# %% [markdown]
# ### GeoManko
#
# To get started, ensure you have an [API key from here](https://developers.google.com/maps) or maybe [here](https://console.cloud.google.com/google/maps-apis/credentials) if you cannot find it...im logged in so i cant see: I will use the following API to get return the location given the SSID keys https://developers.google.com/maps/documentation/geolocation/requests-geolocation#wifi_access_point_object

# %% [markdown]
# ### Install Python libraries
#
# Run the following command (minus the exclamation portion in a terminal) or run this cell in the notebook

# %%
# !pip install python-dotenv requests
# Out:
# Requirement already satisfied: python-dotenv in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests) (2023.7.22)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Load your api key
#
# This will load the API key, before editing it, ensure you change the ```"your_api_key"``` or create a ```.env``` file with the key in the format ```API_KEY="MY_KEY"```

# %%
import os
from dotenv import load_dotenv

# Load .env file
load_dotenv()

# Set default API key value
default_api_key = "your_api_key"

# Read API key from .env file or use the default
api_key = os.getenv('API_KEY', default_api_key)

print("API Key:", api_key)

# %% [markdown]
# ### Get the test data
#
# The following code retrieves the input data for the problem

# %%
import requests

# URL of the JSON data
json_url = "https://metaproblems.com/0d96db28b305a8f2504d7a9f9be044c0/phonedata.json"

# Making a request to get the JSON data
response = requests.get(json_url)

# Checking if the request was successful
if response.status_code == 200:
    # Parsing the JSON data
    json_data = response.json()
else:
    json_data = None
    print("Failed to retrieve data. Status code:", response.status_code)

# Use json_data as needed
json_data
# Out:
# [{'ssid': 'VEC Guest Gate',
#   'bssid': '00:12:0E:89:CA:1B',
#   'channel': '11',
#   'rssi': '-88'},
#  {'ssid': 'RAI-SIGNAGE',
#   'bssid': '00:30:44:54:86:96',
#   'channel': '11',
#   'rssi': '-88'},
#  {'ssid': 'HotspotCCA9',
#   'bssid': '00:54:AF:5B:CC:A9',
#   'channel': '8',
#   'rssi': '-88'},
#  {'ssid': 'vendorwifi',
#   'bssid': '02:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-88'},
#  {'ssid': '', 'bssid': '02:8D:DB:93:68:70', 'channel': '11', 'rssi': '-88'},
#  {'ssid': '', 'bssid': '02:8D:DB:93:69:8C', 'channel': '6', 'rssi': '-88'},
#  {'ssid': 'Taco Bell WiFi',
#   'bssid': '06:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-88'},
#  {'ssid': '', 'bssid': '06:8D:DB:93:68:70', 'channel': '11', 'rssi': '-86'},
#  {'ssid': '', 'bssid': '06:8D:DB:93:69:8C', 'channel': '6', 'rssi': '-89'},
#  {'ssid': 'Tiger Fuel Private',
#   'bssid': '06:EC:DA:A4:C5:16',
#   'channel': '5',
#   'rssi': '-88'},
#  {'ssid': 'Tiger Fuel Private',
#   'bssid': '06:EC:DA:A5:C5:16',
#   'channel': '36',
#   'rssi': '-87'},
#  {'ssid': 'Iwifi',
#   'bssid': '0A:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-89'},
#  {'ssid': '', 'bssid': '0A:8D:DB:93:68:70', 'channel': '11', 'rssi': '-86'},
#  {'ssid': '', 'bssid': '0A:8D:DB:93:69:8C', 'channel': '6', 'rssi': '-90'},
#  {'ssid': '', 'bssid': '0A:EC:DA:A5:C5:16', 'channel': '36', 'rssi': '-88'},
#  {'ssid': 'SLEEP INN OFFICE',
#   'bssid': '0C:80:63:77:1B:34',
#   'channel': '2',
#   'rssi': '-89'},
#  {'ssid': '', 'bssid': '0C:8D:DB:93:68:70', 'channel': '11', 'rssi': '-84'},
#  {'ssid': '', 'bssid': '0C:8D:DB:93:69:8C', 'channel': '6', 'rssi': '-89'},
#  {'ssid': 'serviceswifi',
#   'bssid': '0E:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-90'},
#  {'ssid': 'VIOFO_A129_c92d13',
#   'bssid': '10:D0:7A:C9:2D:13',
#   'channel': '1',
#   'rssi': '-91'},
#  {'ssid': 'HM Device Wifi',
#   'bssid': '16:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-88'},
#  {'ssid': 'HM Device Wifi',
#   'bssid': '16:8D:DB:93:68:70',
#   'channel': '11',
#   'rssi': '-85'},
#  {'ssid': 'HM Device Wifi',
#   'bssid': '16:8D:DB:93:69:8C',
#   'channel': '6',
#   'rssi': '-89'},
#  {'ssid': 'Shell1',
#   'bssid': '1C:9E:CC:27:85:D7',
#   'channel': '6',
#   'rssi': '-78'},
#  {'ssid': '', 'bssid': '26:8D:DB:93:68:70', 'channel': '11', 'rssi': '-83'},
#  {'ssid': '', 'bssid': '26:8D:DB:93:69:8C', 'channel': '6', 'rssi': '-89'},
#  {'ssid': 'XFINITY',
#   'bssid': '28:7A:EE:84:01:BA',
#   'channel': '153',
#   'rssi': '-80'},
#  {'ssid': 'xfinitywifi',
#   'bssid': '28:7A:EE:84:01:BB',
#   'channel': '153',
#   'rssi': '-79'},
#  {'ssid': 'CableWiFi',
#   'bssid': '28:7A:EE:84:01:BC',
#   'channel': '153',
#   'rssi': '-81'},
#  {'ssid': 'CoxWiFi',
#   'bssid': '28:7A:EE:84:01:BF',
#   'channel': '153',
#   'rssi': '-80'},
#  {'ssid': 'XFINITY',
#   'bssid': '28:7A:EE:84:02:FA',
#   'channel': '161',
#   'rssi': '-63'},
#  {'ssid': 'xfinitywifi',
#   'bssid': '28:7A:EE:84:02:FB',
#   'channel': '161',
#   'rssi': '-74'},
#  {'ssid': 'CableWiFi',
#   'bssid': '28:7A:EE:84:02:FC',
#   'channel': '161',
#   'rssi': '-64'},
#  {'ssid': 'CoxWiFi',
#   'bssid': '28:7A:EE:84:02:FF',
#   'channel': '161',
#   'rssi': '-64'},
#  {'ssid': 'IRT Wifi',
#   'bssid': '2A:8D:CB:93:69:8C',
#   'channel': '48',
#   'rssi': '-89'},
#  {'ssid': 'XFINITY',
#   'bssid': '5A:B2:03:67:29:C0',
#   'channel': '36',
#   'rssi': '-91'},
#  {'ssid': 'xfinitywifi',
#   'bssid': '5E:B2:03:67:29:C0',
#   'channel': '36',
#   'rssi': '-91'},
#  {'ssid': 'CBCI-108D',
#   'bssid': '88:9E:68:69:10:91',
#   'channel': '11',
#   'rssi': '-89'},
#  {'ssid': '', 'bssid': '8A:9E:68:69:11:92', 'channel': '11', 'rssi': '-89'},
#  {'ssid': 'BROADCOM_GUEST_0_6',
#   'bssid': '8A:9E:68:69:11:97',
#   'channel': '11',
#   'rssi': '-86'},
#  {'ssid': 'Ledesma',
#   'bssid': 'B2:00:73:EB:26:FC',
#   'channel': '44',
#   'rssi': '-93'},
#  {'ssid': 'Ledesma',
#   'bssid': 'B2:00:73:FB:26:FC',
#   'channel': '6',
#   'rssi': '-86'},
#  {'ssid': 'ljblack',
#   'bssid': 'BC:82:5D:1B:5C:DC',
#   'channel': '6',
#   'rssi': '-85'},
#  {'ssid': 'CBCI-C1C0-2.4',
#   'bssid': 'C0:7C:D1:07:A4:38',
#   'channel': '1',
#   'rssi': '-88'},
#  {'ssid': 'NETGEAR06',
#   'bssid': 'D4:5D:DF:46:2C:68',
#   'channel': '1',
#   'rssi': '-86'},
#  {'ssid': '', 'bssid': 'E0:CB:BC:35:06:3A', 'channel': '1', 'rssi': '-88'},
#  {'ssid': '', 'bssid': 'E0:CB:BC:35:1A:D0', 'channel': '11', 'rssi': '-82'},
#  {'ssid': '', 'bssid': 'E2:CB:AC:35:06:3A', 'channel': '112', 'rssi': '-91'},
#  {'ssid': '', 'bssid': 'E2:CB:AC:35:1A:D0', 'channel': '104', 'rssi': '-92'},
#  {'ssid': 'Public WiFi Default',
#   'bssid': 'E4:D1:24:36:02:E1',
#   'channel': '1',
#   'rssi': '-87'},
#  {'ssid': 'NETGEAR73',
#   'bssid': 'E4:F4:C6:10:F4:62',
#   'channel': '11',
#   'rssi': '-84'},
#  {'ssid': 'BKOffice',
#   'bssid': 'F2:23:FF:60:CD:A2',
#   'channel': '11',
#   'rssi': '-88'},
#  {'ssid': 'VTEAM',
#   'bssid': 'F4:2E:7F:1C:5F:D1',
#   'channel': '48',
#   'rssi': '-89'},
#  {'ssid': 'vz-guest',
#   'bssid': 'F4:2E:7F:1C:5F:D2',
#   'channel': '48',
#   'rssi': '-89'},
#  {'ssid': 'CBCI-CECE',
#   'bssid': 'F8:D2:AC:C5:CE:D3',
#   'channel': '157',
#   'rssi': '-85'}]

# %% [markdown]
# ### Create the request
#
# I need to put the data in a format shown by the [documentation](https://developers.google.com/maps/documentation/geolocation/requests-geolocation#wifi_access_point_object)
#
# and then create the request and print out the result

# %%
import json 

def convert_key_names(json_data, old_key, new_key):
    """
    Converts specified key names in a JSON object.

    :param json_data: A JSON object (dict in Python) that may contain the old_key.
    :param old_key: The key name to be replaced.
    :param new_key: The new key name to replace old_key.
    :return: A new JSON object with old_key replaced by new_key.
    """
    if isinstance(json_data, dict):
        return {new_key if key == old_key else key: convert_key_names(value, old_key, new_key) for key, value in json_data.items()}
    elif isinstance(json_data, list):
        return [convert_key_names(item, old_key, new_key) for item in json_data]
    else:
        return json_data

wrapped_data = {
    "considerIp": "false",
    "wifiAccessPoints": json_data
}

#convert the names to match googles API
wrapped_data= convert_key_names(wrapped_data,'bssid','macAddress')
wrapped_data= convert_key_names(wrapped_data,'rssi','signalStrength')

# URL for the Google Geolocation API
url = f"https://www.googleapis.com/geolocation/v1/geolocate?key={api_key}"

# Make the POST request
response = requests.post(url, headers={"Content-Type": "application/json"}, data=json.dumps(wrapped_data))

# Print response (or handle it as needed)
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "location": {
#     "lat": 38.0114668,
#     "lng": -78.5033922
#   },
#   "accuracy": 55.824
# }
